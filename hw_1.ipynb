# %% [markdown]
# # 과제 1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd drive/My Drive/........

# %% [markdown]
# 1. github의 수업자료 repository로부터 hw_1.npy를 ndarray 형태로 읽어들여 hw_1 에 저장하시오. (힌트: pandas/ch_04_Numpy_Basics.ipynb의 4.4절 참고)

# %% [markdown]
# 2. hw_1의 data type이 numpy.ndarray 임을 확인하시오.

# %% [markdown]
# #### hw_1을 data로 이용하여 pytorch를 이용하여 독립변수($x_1$, $x_2$)가 2개이고 종속변수($y_1$)가 1개인 Linear Regression의 모형에 대하여 다음 물음에 답하시오.

# %% [markdown]
# 3. x_train은 hw_1의 0열 ~ 1열이고, y_train은 hw_1의 2열이다.
# 이를 코딩하시오.

# %%
x_train =
y_train =

# %% [markdown]
# 4. epoch = 1000, learning rate 0.001, optimizer SGD, loss function MSE 로 정하고, nn.Module을 이용하여, $W$와 $b$를 구하시오. (프로그램 코드를 실행한 후 저장하여 제출)
